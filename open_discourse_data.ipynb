# %%
import pandas as pd

# %%
df = pd.read_csv("data/open_discourse/contributions_extended.csv", nrows=100)
df
# Out:
#     id             type firstName lastName  politicianId  \
# 0    0           Lachen       NaN      NaN            -1
# 1    1  Personen-Einruf       NaN   hütter      11000979
# 2    2            Zuruf       NaN      NaN            -1
# 3    3            Zuruf       NaN      NaN            -1
# 4    4  Personen-Einruf       NaN  blücher      11000202
# ..  ..              ...       ...      ...           ...
# 95  94           Lachen       NaN      NaN            -1
# 96  95       Zustimmung       NaN      NaN            -1
# 97  96            Zuruf       NaN      NaN            -1
# 98  97  Personen-Einruf       NaN   Renner      11001823
# 99  98          Beifall   bei der      SPD            -1
#
#                                               content  speechId  textPosition  \
# 0                                               links         6             7
# 1                                               Nein!         6             2
# ...

# %%
df = pd.read_csv("data/open_discourse/contributions_simplified.csv", nrows=100)
df
# Out:
#     id  textPosition  speechId  \
# 0    0             0         2
# 1    1             4         5
# 2    2             3         5
# 3    3             2         5
# 4    4             1         5
# ..  ..           ...       ...
# 95  95            30        52
# 96  96            29        52
# 97  97            28        52
# 98  98            27        52
# 99  99            26        52
#
#                                               content
# 0           (Der Bundespräsident leistet diesen Eid.)
# 1           (dem Bundespräsidenten die Hand reichend)
# 2                (Langanhaltender lebhafter Beifall.)
# 3                         (Bundespräsident Dr. Heuss)
# 4                                     (Sehr richtig!)
# ..                                                ...
# 95                       (Bundeskanzler Dr. Adenauer)
# 96                          (Sehr gut! in der Mitte.)
# 97  (Hört! Hört! bei der KPD. - Abg. Renner: Nur „...
# ...

# %%
df = pd.read_csv("data/open_discourse/factions.csv", nrows=100)
df
# Out:
#     id  abbreviation                                           fullName
# 0   -1     not found                                          not found
# 1    0           AfD                        Alternative für Deutschland
# 2    1           BHE      Block der Heimatvertriebenen und Entrechteten
# 3    2            BP                                       Bayernpartei
# 4    3         Grüne                              Bündnis 90/Die Grünen
# 5    4       CDU/CSU  Christlich Demokratische Union Deutschlands/Ch...
# 6    5            DA                  Demokratische Arbeitsgemeinschaft
# 7    6    DIE LINKE.                                         DIE LINKE.
# 8    7            DP                                    Deutsche Partei
# 9    8        DP/DBP             Deutsche Partei/Deutsche Partei Bayern
# 10   9        DP/FVP                  Deutsche Partei/Freie Volkspartei
# 11  10           DPB                             Deutsche Partei Bayern
# ...

# %%
df = pd.read_csv("data/open_discourse/politicians.csv")
df
# Out:
#             id  firstName   lastName  \
# 0     11000001    Manfred    Abelein
# 1     11000002      Ernst  Achenbach
# 2     11000003  Annemarie  Ackermann
# 3     11000004       Else  Ackermann
# 4     11000005     Ulrich       Adam
# ...        ...        ...        ...
# 4097  11004971    Manuela   Schwesig
# 4098  11004972    Manfred     Stolpe
# 4099  11004973    Johanna      Wanka
# 4100  11004974     Ludger   Westrick
# 4101        -1  Not found        NaN
#
#                                        birthPlace birthCountry   birthDate  \
# 0                                       Stuttgart  Deutschland  1930-10-20
# 1                                          Siegen  Deutschland  1909-04-09
# 2                                      Parabutsch  Jugoslawien  1913-05-26
# 3                                          Berlin  Deutschland  1933-11-06
# 4     Teterow, Kr. Teterow, Bezirk Neubrandenburg  Deutschland  1950-06-09
# ...

# %%
df = pd.read_csv("data/open_discourse/speeches.csv", nrows=100, parse_dates=["date"])
df
# Out:
#     id  session  electoralTerm firstName lastName  politicianId  \
# 0    0        2              1       NaN   Köhler      11001150
# 1    1        2              1       NaN   Arnold            -1
# 2    2        2              1       NaN   Köhler      11001150
# 3    3        2              1       NaN    Heuss            -1
# 4    4        2              1       NaN   Köhler      11001150
# ..  ..      ...            ...       ...      ...           ...
# 95  94        7              1       NaN   Seelos      11002141
# 96  96        7              1       NaN   Seelos      11002141
# 97  97        7              1       NaN   Köhler      11001150
# 98  98        7              1       NaN   Seelos      11002141
# 99  99        7              1       NaN   Köhler      11001150
#
#                                         speechContent  factionId  \
# 0   Meine Damen und Herren! Ich eröffne die 2. Sit...         -1
# ...

# %%
df["positionShort"].unique()
# Out:
# array(['Presidium of Parliament', 'Guest', 'Member of Parliament',
#        'Minister', 'Chancellor'], dtype=object)

# %%
df["date"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df["date"][99]
# Out:
# Timestamp('1949-09-22 00:00:00')
