# %%
import pandas as pd
import plotly.express as px

from src.utils import show, parse_config
from src.data_prep import prepare_faction_data, prepare_politician_data

CONFIG = parse_config()

# %%
# speech df already fully processed
df_speeches = pd.read_pickle(CONFIG["processed_df_cache"])
df_faction = prepare_faction_data()
df_faction
# Out:
#        faction_id faction_abbreviation  \
# index
# 0              -1            not found
# 1               0                  AfD
# 2               1                  BHE
# 3               2                   BP
# 4               3                Grüne
# 5               4              CDU/CSU
# 6               5                   DA
# 7               6           DIE LINKE.
# 8               7                   DP
# 9               8               DP/DBP
# 10              9               DP/FVP
# 11             10                  DPB
# 12             11                  DRP
# 13             12               DRP/NR
# 14             13                  FDP
# 15             14                   FU
# 16             15                  FVP
# 17             16         Fraktionslos
# 18             17               GB/BHE
# 19             18                 Gast
# 20             19                   KO
# 21             20                  KPD
# 22             21                   NR
# 23             22                  PDS
# 24             23                  SPD
# 25             24                  SSW
# 26             25                  WAV
# 27             26                    Z
#
#                                             faction_name
# index
# 0                                              not found
# 1                            Alternative für Deutschland
# 2          Block der Heimatvertriebenen und Entrechteten
# 3                                           Bayernpartei
# 4                                  Bündnis 90/Die Grünen
# 5      Christlich Demokratische Union Deutschlands/Ch...
# 6                      Demokratische Arbeitsgemeinschaft
# 7                                             DIE LINKE.
# 8                                        Deutsche Partei
# 9                 Deutsche Partei/Deutsche Partei Bayern
# 10                     Deutsche Partei/Freie Volkspartei
# 11                                Deutsche Partei Bayern
# 12                                 Deutsche Reformpartei
# 13                Deutsche Reichspartei/Nationale Rechte
# 14                            Freie Demokratische Partei
# 15                                 Föderalistische Union
# 16                                     Freie Volkspartei
# 17                                          Fraktionslos
# 18     Gesamtdeutscher Block/Bund der Heimatvertriebe...
# 19                                                  Gast
# 20                               Kraft/Oberländer-Gruppe
# 21                    Kommunistische Partei Deutschlands
# 22                                      Nationale Rechte
# 23                 Partei des Demokratischen Sozialismus
# 24               Sozialdemokratische Partei Deutschlands
# 25                       Südschleswigscher Wählerverband
# 26                    Wirtschaftliche Aufbau-Vereinigung
# 27                               Deutsche Zentrumspartei

# %%
df = pd.merge(
    df_speeches, df_faction, how="left", left_on="faction_id", right_on="faction_id"
)

# %%
df_politicians = prepare_politician_data()
df_politicians
# Out:
#       politician_id first_name  last_name  \
# 0          11000001    Manfred    Abelein
# 1          11000002      Ernst  Achenbach
# 2          11000003  Annemarie  Ackermann
# 3          11000004       Else  Ackermann
# 4          11000005     Ulrich       Adam
# ...             ...        ...        ...
# 4097       11004971    Manuela   Schwesig
# 4098       11004972    Manfred     Stolpe
# 4099       11004973    Johanna      Wanka
# 4100       11004974     Ludger   Westrick
# 4101             -1  Not found        NaN
#
#                                       birth_place birth_country  birth_date  \
# 0                                       Stuttgart   Deutschland  1930-10-20
# 1                                          Siegen   Deutschland  1909-04-09
# 2                                      Parabutsch   Jugoslawien  1913-05-26
# 3                                          Berlin   Deutschland  1933-11-06
# 4     Teterow, Kr. Teterow, Bezirk Neubrandenburg   Deutschland  1950-06-09
# ...                                           ...           ...         ...
# 4097                                          NaN           NaN         NaN
# 4098                                          NaN           NaN         NaN
# 4099                                          NaN           NaN         NaN
# 4100                                          NaN           NaN         NaN
# 4101                                          NaN           NaN         NaN
#
#       death_date    gender                                         profession  \
# 0     2008-01-17  männlich  Rechtsanwalt, Wirtschaftsprüfer, Universitätsp...
# 1     1991-12-02  männlich                             Rechtsanwalt und Notar
# 2     1994-02-18  weiblich                                    Hilfsreferentin
# 3     2019-09-14  weiblich                                             Ärztin
# 4            NaN  männlich                      Mathematiker, Geschäftsführer
# ...          ...       ...                                                ...
# 4097         NaN       NaN                                                NaN
# 4098         NaN       NaN                                                NaN
# 4099         NaN       NaN                                                NaN
# 4100         NaN       NaN                                                NaN
# 4101         NaN       NaN                                                NaN
#
#      aristocracy academic_title                  full_name
# 0            NaN      Prof. Dr.  Prof. Dr. Manfred Abelein
# 1            NaN            Dr.        Dr. Ernst Achenbach
# 2            NaN            NaN        Annemarie Ackermann
# 3            NaN            Dr.         Dr. Else Ackermann
# 4            NaN            NaN                Ulrich Adam
# ...          ...            ...                        ...
# 4097         NaN            NaN           Manuela Schwesig
# 4098         NaN            NaN             Manfred Stolpe
# 4099         NaN            NaN              Johanna Wanka
# 4100         NaN            NaN            Ludger Westrick
# 4101         NaN            NaN                        NaN
#
# [4102 rows x 12 columns]

# %%
df = pd.merge(df, df_politicians, how="left", on="politician_id", suffixes=("_speech", "_master"))
df
# Out:
#        index       id  session  electoral_term first_name_speech  \
# 0          0      144        7               1               NaN
# 1          1      237        9               1               NaN
# 2          2      239        9               1               NaN
# 3          3      224        9               1               NaN
# 4          4      231        9               1               NaN
# ...      ...      ...      ...             ...               ...
# 24533  24533  1052422      202              19            Oliver
# 24534  24534  1052424      202              19           Andreas
# 24535  24535  1052426      202              19            Johann
# 24536  24536  1052644      202              19           Manfred
# 24537  24537  1052804      202              19           Michael
#
#       last_name_speech  politician_id  \
# 0           Wellhausen       11002468
# 1               rische       11001857
# 2               loritz       11001375
# 3             adenauer       11000009
# 4       höpker-aschoff       11000927
# ...                ...            ...
# 24533         Krischer       11004081
# 24534             Lenz       11004339
# 24535         Saathoff       11004393
# 24536     Todtenhausen       11004222
# 24537     von Abercron       11004650
#
#                                                     text  faction_id  \
# 0      Meine verehrten Damen und Herren! Ich hatte di...          13
# 1      Meine Damen und Herren! Seit einigen Tagen wir...          20
# 2      Meine sehr verehrten Damen und Herren! Ich gla...          25
# 3      Ich habe dem Hohen Hause im Namen der Bundesre...          -1
# 4      Meine Damen und Herren! Als uns vor einigen Mo...          13
# ...                                                  ...         ...
# 24533   Auf die Polemik am Schluss muss man gar nicht...           3
# 24534   Sehr geehrter Herr Präsident! Sehr geehrte Da...           4
# 24535   Sehr geehrter Herr Präsident! Liebe Kolleginn...          23
# 24536   Herr Präsident, ich gönne Ihnen die Atempause...          13
# 24537   Sehr geehrte Frau Präsidentin! Liebe Kollegin...           4
#
#                                             document_url  ...  \
# 0      https://dip21.bundestag.de/dip21/btp/01/01007.pdf  ...
# 1      https://dip21.bundestag.de/dip21/btp/01/01009.pdf  ...
# 2      https://dip21.bundestag.de/dip21/btp/01/01009.pdf  ...
# 3      https://dip21.bundestag.de/dip21/btp/01/01009.pdf  ...
# 4      https://dip21.bundestag.de/dip21/btp/01/01009.pdf  ...
# ...                                                  ...  ...
# 24533  https://dip21.bundestag.de/dip21/btp/19/19202.pdf  ...
# 24534  https://dip21.bundestag.de/dip21/btp/19/19202.pdf  ...
# 24535  https://dip21.bundestag.de/dip21/btp/19/19202.pdf  ...
# 24536  https://dip21.bundestag.de/dip21/btp/19/19202.pdf  ...
# 24537  https://dip21.bundestag.de/dip21/btp/19/19202.pdf  ...
#
#       last_name_master        birth_place birth_country  birth_date  \
# 0           Wellhausen  Münder / Hannover   Deutschland  1894-09-19
# 1               Rische             Bochum   Deutschland  1914-12-25
# 2               Loritz            München   Deutschland  1902-04-24
# 3             Adenauer               Köln   Deutschland  1876-01-05
# 4       Höpker-Aschoff            Herford   Deutschland  1883-01-31
# ...                ...                ...           ...         ...
# 24533         Krischer            Zülpich   Deutschland  1969-07-26
# 24534             Lenz          Ebersberg   Deutschland  1981-04-23
# 24535         Saathoff              Emden   Deutschland  1967-12-09
# 24536     Todtenhausen          Wuppertal   Deutschland  1950-12-08
# 24537         Abercron         Ehlerstorf   Deutschland  1952-11-17
#
#        death_date    gender                                   profession  \
# 0      1964-09-03  männlich          Regierungsrat a. D., Fabrikdirektor
# 1      2007-11-22  männlich                                    Redakteur
# 2      1979-04-14  männlich                                 Rechtsanwalt
# 3      1967-04-19  männlich                          Bundeskanzler a. D.
# 4      1954-01-15  männlich  Präsident des Bundesverfassungsgericht a.D.
# ...           ...       ...                                          ...
# 24533         NaN  männlich               Wissenschaftlicher Mitarbeiter
# 24534         NaN  männlich           Kreisrat, Diplom-Betriebswirt (FH)
# 24535         NaN  männlich                  Diplom-Verwaltungswirt (FH)
# 24536         NaN  männlich              Elektromeister, Geschäftsführer
# 24537         NaN  männlich                         Dipl.-Agraringenieur
#
#       aristocracy academic_title                   full_name
# 0             NaN            Dr.         Dr. Hans Wellhausen
# 1             NaN            NaN            Friedrich Rische
# 2             NaN            NaN               Alfred Loritz
# 3             NaN            Dr.         Dr. Konrad Adenauer
# 4             NaN            Dr.  Dr. Hermann Höpker-Aschoff
# ...           ...            ...                         ...
# 24533         NaN            NaN             Oliver Krischer
# 24534         NaN            Dr.            Dr. Andreas Lenz
# 24535         NaN            NaN             Johann Saathoff
# 24536         NaN            NaN        Manfred Todtenhausen
# 24537         NaN            Dr.        Dr. Michael Abercron
#
# [24538 rows x 61 columns]

# %%
df = df.dropna(subset=["faction_abbreviation"])

# %%
df.columns
# Out:
# Index(['index', 'id', 'session', 'electoral_term', 'first_name_speech',
#        'last_name_speech', 'politician_id', 'text', 'faction_id',
#        'document_url', 'position_short', 'position_long', 'date',
#        'after_shock', 'doc_index', 'speech_length', 'keyword_counter',
#        'keywords', 'AN_descriptive', 'AN_s', 'PN_descriptive', 'PN_s',
#        'NE_descriptive', 'NE_s', 'CE_descriptive', 'CE_s',
#        'subtree_length_counter', 'ancestors_length_counter',
#        'negation_counter', 'third_person_counter', 'score_neutral_counter',
#        'score_positive_counter', 'score_negative_counter', 'AN_sp', 'AN_sa',
#        'PN_sp', 'PN_sa', 'NE_sp', 'NE_sa', 'CE_sp', 'CE_sa', 'score',
#        'score_p', 'score_a', 'weight', 'w_score', 'w_score_p', 'w_score_a',
#        'faction_abbreviation', 'faction_name', 'first_name_master',
#        'last_name_master', 'birth_place', 'birth_country', 'birth_date',
#        'death_date', 'gender', 'profession', 'aristocracy', 'academic_title',
#        'full_name'],
#       dtype='object')

# %%
fig = px.scatter(
        df.query("w_score != 0"),
        x="date",
        y="w_score",
        color="faction_abbreviation",
        color_discrete_map=CONFIG["party_colors"],
        size="speech_length",
        opacity=0.5,
        title=f"Speeches on Energy Politics",
        custom_data=["index","full_name", "profession","faction_name"],
        labels={"faction_abbreviation": "Faction"},
        category_orders={"faction_abbreviation": ["SPD","CDU/CSU","Grüne","FDP","DIE LINKE.","AfD","PDS","Fraktionslos","not found"]}
    )
fig.update_traces(hovertemplate="%{customdata[1]}<br>%{customdata[2]}<br>%{customdata[3]}")
fig.show()

# %%
fig.write_html("nb_07_energy_politics_timeline.html")
